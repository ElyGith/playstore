# %%
import pandas as pd
#Bloc de configuration

pd.set_option('display.width', 200)  # Largeur totale
pd.set_option('display.max_colwidth', 50)  # Largeur par colonne

pd.set_option('display.max_columns', None)  # Afficher toutes les colonnes

# %%
# Fichier sur lequel on va travailler 
df = pd.read_csv('../data/googleplaystore.csv',sep=',')

# %%
df.sample(5)
# Out:
#                                        App        Category  Rating Reviews  Size  Installs  Type Price Content Rating         Genres        Last Updated Current Ver   Android Ver
# 32               Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035   11M  100,000+  Free     0       Everyone   Art & Design       July 19, 2018        2.20    4.0 and up
# 3602                  White Noise for Baby       PARENTING     4.9     717  6.6M  100,000+  Free     0       Everyone      Parenting   December 30, 2017       1.6.0    4.1 and up
# 10321                           FE Connect           TOOLS     4.8      24  4.5M    5,000+  Free     0       Everyone          Tools  September 14, 2017       2.3.0  4.0.3 and up
# 5426   Scanning body and undressing people          FAMILY     3.4    1012   12M  100,000+  Free     0           Teen  Entertainment   February 24, 2018         2.0    3.0 and up
# 6349                  KISW 99.9 FM SEATTLE          FAMILY     4.0    1469  5.2M  100,000+  Free     0       Everyone  Entertainment    January 29, 2018      2.1.10  2.3.3 and up

# %%
#1474 valeurs nulle pour les rating
df[df['Rating'].isnull()]
# Out:
#                                        App             Category  Rating Reviews  Size  Installs  Type Price Content Rating                           Genres        Last Updated Current Ver  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN      61  7.0M  100,000+  Free     0       Everyone  Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113              Wrinkles and rejuvenation               BEAUTY     NaN     182  5.7M  100,000+  Free     0   Everyone 10+                           Beauty  September 20, 2017         8.0
# 123                 Manicure - nail design               BEAUTY     NaN     119  3.7M   50,000+  Free     0       Everyone                           Beauty       July 23, 2018         1.3
# 126           Skin Care and Natural Beauty               BEAUTY     NaN     654  7.4M  100,000+  Free     0           Teen                           Beauty       July 17, 2018        1.15
# 129    Secrets of beauty, youth and health               BEAUTY     NaN      77  2.9M   10,000+  Free     0     Mature 17+                           Beauty      August 8, 2017         2.0
# ...                                    ...                  ...     ...     ...   ...       ...   ...   ...            ...                              ...                 ...         ...
# 10824                            Cardio-FR              MEDICAL     NaN      67   82M   10,000+  Free     0       Everyone                          Medical       July 31, 2018       2.2.2
# 10825                   Naruto & Boruto FR               SOCIAL     NaN       7  7.7M      100+  Free     0           Teen                           Social    February 2, 2018         1.0
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN      38  9.8M    5,000+  Free     0       Everyone                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                             FR Forms             BUSINESS     NaN       0  9.6M       10+  Free     0       Everyone                         Business  September 29, 2016       1.1.5
# 10838               Parkinson Exercices FR              MEDICAL     NaN       3  9.5M    1,000+  Free     0       Everyone                          Medical    January 20, 2017         1.0
#
#       Android Ver
# 23     4.1 and up
# 113    3.0 and up
# 123    4.1 and up
# 126    4.1 and up
# 129    2.3 and up
# ...           ...
# 10824  4.4 and up
# 10825  4.0 and up
# 10831  4.0 and up
# 10835  4.0 and up
# 10838  2.2 and up
#
# [1474 rows x 13 columns]

# %%
#Suppresions des valeurs NaN car inutilisable
df = df.dropna(subset=['Rating'])

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
df[df['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating Reviews    Size Installs Type     Price Content Rating             Genres Last Updated Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M  1,000+     Free    0  Everyone            NaN  February 11, 2018       1.0.19  4.0 and up         NaN

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                   App            Category  Rating Reviews  Size    Installs  Type  Price Content Rating            Genres       Last Updated Current Ver Android Ver
# 15    Learn To Draw Kawaii Characters      ART_AND_DESIGN     3.2      55  2.7M      5,000+  Free      0       Everyone      Art & Design       June 6, 2018         NaN  4.2 and up
# 1553             Market Update Helper  LIBRARIES_AND_DEMO     4.1   20145   11k  1,000,000+  Free      0       Everyone  Libraries & Demo  February 12, 2013         NaN  1.5 and up
# 6322           Virtual DJ Sound Mixer               TOOLS     4.2    4010  8.7M    500,000+  Free      0       Everyone             Tools       May 10, 2017         NaN  4.0 and up
# 7333                      Dots puzzle              FAMILY     4.0     179   14M     50,000+  Paid  $0.99       Everyone            Puzzle     April 18, 2018         NaN  4.0 and up

# %%
df[df['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  Type  Price Content Rating           Genres    Last Updated Current Ver Android Ver
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4         NaN
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+  Free      0       Everyone  Personalization  March 27, 2018         1.1         NaN

# %%
# Suppresion des valeurs anormales ou null
# Les autres ont peut les laisser car non nécéssaire à notre analyse 
df = df.drop(10472)

# %%
df["Reviews"] = df["Reviews"].astype(int)

# %%
#On va normaliser Size pour pouvoir le passer en int
# k pour 10^3 et M pour 10^6
